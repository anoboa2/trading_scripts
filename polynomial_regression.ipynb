# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
# create ticker objects for our two securities that we will compare
spy = yf.Ticker('SPY')
tsla = yf.Ticker('TSLA')

# %%
# pull pricing data for our equities using the yf method history
spy_h = spy.history(period='30d', interval='60m')
tsla_h = tsla.history(period='30d', interval='60m')

# %%
# split up training data and testing data from our historical data objects
X_train, X_test, y_train, y_test = train_test_split(spy_h.index, spy_h['Close'], test_size=0.2, random_state=0)

# %%
# messing around here
poly_reg = PolynomialFeatures(degree=5)
X_poly = poly_reg.fit_transform(X_train)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <module>
#       1 # messing around here
#       2 poly_reg = PolynomialFeatures(degree=5)
# ----> 3 X_poly = poly_reg.fit_transform(X_train)
#       4 pol_reg = LinearRegression()
#       5 pol_reg.fit(X_poly, y_train)
#
# File ~/.local/share/virtualenvs/trading_scripts-2QlzeJCK/lib/python3.9/site-packages/sklearn/base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
# ...
